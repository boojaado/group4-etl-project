# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
filepath = "countries_of_the_world.csv"

# %%
df = pd.read_csv(filepath)
df.head(10)
# Out:
#               Country                               Region  Population  \
# 0        Afghanistan         ASIA (EX. NEAR EAST)             31056997
# 1            Albania   EASTERN EUROPE                          3581655
# 2            Algeria   NORTHERN AFRICA                        32930091
# 3     American Samoa   OCEANIA                                   57794
# 4            Andorra   WESTERN EUROPE                            71201
# 5             Angola   SUB-SAHARAN AFRICA                     12127071
# 6           Anguilla               LATIN AMER. & CARIB           13477
# 7  Antigua & Barbuda               LATIN AMER. & CARIB           69108
# 8          Argentina               LATIN AMER. & CARIB        39921833
# 9            Armenia                  C.W. OF IND. STATES      2976372
#
#    Area (sq. mi.) Pop. Density (per sq. mi.) Coastline (coast/area ratio)  \
# 0          647500                       48,0                         0,00
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 227 entries, 0 to 226
# Data columns (total 20 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Country                             227 non-null    object
#  1   Region                              227 non-null    object
#  2   Population                          227 non-null    int64
#  3   Area (sq. mi.)                      227 non-null    int64
#  4   Pop. Density (per sq. mi.)          227 non-null    object
#  5   Coastline (coast/area ratio)        227 non-null    object
#  6   Net migration                       224 non-null    object
#  7   Infant mortality (per 1000 births)  224 non-null    object
#  8   GDP ($ per capita)                  226 non-null    float64
#  9   Literacy (%)                        209 non-null    object
#  10  Phones (per 1000)                   223 non-null    object
# ...

# %%
df2 = df.drop(columns=["Region","Area (sq. mi.)", "Pop. Density (per sq. mi.)", "Coastline (coast/area ratio)", "Net migration","Literacy (%)", "Phones (per 1000)", "Arable (%)", "Crops (%)", "Other (%)", "Climate", "Agriculture", "Industry", "Service"])
df2.head()
# Out:
#            Country  Population Infant mortality (per 1000 births)  \
# 0     Afghanistan     31056997                             163,07
# 1         Albania      3581655                              21,52
# 2         Algeria     32930091                                 31
# 3  American Samoa        57794                               9,27
# 4         Andorra        71201                               4,05
#
#    GDP ($ per capita) Birthrate Deathrate
# 0               700.0      46,6     20,34
# 1              4500.0     15,11      5,22
# 2              6000.0     17,14      4,61
# 3              8000.0     22,46      3,27
# 4             19000.0      8,71      6,25

# %%
df2.to_csv("CountryData.csv", index=False)

# %%
filepath2 = "CountryData.csv"

# %%
df3 = pd.read_csv(filepath2)
df3
# Out:
#    country_code         country  population  infant_mortality    gdp  \
# 0            AU      Australia     20264082              4.69  29000
# 1            BR         Brazil    188078227             29.61   7600
# 2            CA         Canada     33098932              4.75  29800
# 3            CN          China   1313973713             24.18   5000
# 4            CI  Cote d'Ivoire     17654843             90.83   1400
# 5            EG          Egypt     78887007             32.59   4000
# 6            IN          India   1095351995             56.29   2900
# 7            MX         Mexico    107449525             20.91   9000
# 8            NG        Nigeria    131859731             98.80    900
# 9            US  United States    298444215              6.50  37800
# 10           ZW       Zimbabwe     12236805             67.69   1900
#
#     birthrate  deathrate
# 0       12.14       7.51
# 1       16.56       6.17
# 2       10.78       7.80
# 3       13.25       6.97
# ...

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11 entries, 0 to 10
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   country_code      11 non-null     object
#  1   country           11 non-null     object
#  2   population        11 non-null     int64
#  3   infant_mortality  11 non-null     float64
#  4   gdp               11 non-null     int64
#  5   birthrate         11 non-null     float64
#  6   deathrate         11 non-null     float64
# dtypes: float64(3), int64(2), object(2)
# memory usage: 744.0+ bytes

# %%
engine = create_engine('postgresql://postgres:password@34.133.202.52/postgres')
df3.to_sql('countries', engine, if_exists='append', index=False)

# %%
engine.dispose()
