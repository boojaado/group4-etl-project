# %%
# Import dependencies
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as st
from scipy.stats import sem
import seaborn as sns
import os

# %%
filepath = "/Users/serendipitousfun/Desktop/Project 2 ETL Group 4/ Resources/vaccinations.csv"

# %%
df = pd.read_csv(filepath)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1813965 entries, 0 to 1813964
# Data columns (total 32 columns):
#  #   Column                                         Dtype
# ---  ------                                         -----
#  0   date                                           object
#  1   location_key                                   object
#  2   new_persons_vaccinated                         float64
#  3   cumulative_persons_vaccinated                  float64
#  4   new_persons_fully_vaccinated                   float64
#  5   cumulative_persons_fully_vaccinated            float64
#  6   new_vaccine_doses_administered                 float64
#  7   cumulative_vaccine_doses_administered          float64
#  8   new_persons_vaccinated_pfizer                  float64
#  9   cumulative_persons_vaccinated_pfizer           float64
#  10  new_persons_fully_vaccinated_pfizer            float64
#  11  cumulative_persons_fully_vaccinated_pfizer     float64
# ...

# %%
df.head(25)
# Out:
#           date location_key  new_persons_vaccinated  \
# 0   2021-01-25           AD                     NaN
# 1   2021-02-01           AD                   460.0
# 2   2021-02-10           AD                   255.0
# 3   2021-02-12           AD                   331.0
# 4   2021-02-19           AD                   519.0
# 5   2021-02-24           AD                   249.0
# 6   2021-02-26           AD                     0.0
# 7   2021-03-08           AD                    49.0
# 8   2021-03-10           AD                  1211.0
# 9   2021-03-15           AD                  3448.0
# 10  2021-03-19           AD                     0.0
# 11  2021-04-04           AD                     0.0
# 12  2021-04-05           AD                  2683.0
# 13  2021-04-11           AD                     0.0
# 14  2021-04-12           AD                     0.0
# 15  2021-04-19           AD                 11952.0
# 16  2021-04-26           AD                  2089.0
# ...

# %%
#pull data out by vacinne provider
df_totals = df.filter(['date', 'location_key', 'new_persons_vaccinated', 'cumulative_persons_vaccinated', 'new_persons_fully_vaccinated', 'cumulative_persons_fully_vaccinated', 'new_vaccine_doses_administered', 'cumulative_vaccine_doses_administered'], axis= 1)
df_totals.head()
# Out:
#          date location_key  new_persons_vaccinated  \
# 0  2021-01-25           AD                     NaN
# 1  2021-02-01           AD                   460.0
# 2  2021-02-10           AD                   255.0
# 3  2021-02-12           AD                   331.0
# 4  2021-02-19           AD                   519.0
#
#    cumulative_persons_vaccinated  new_persons_fully_vaccinated  \
# 0                          576.0                           NaN
# 1                         1036.0                           NaN
# 2                         1291.0                           NaN
# 3                         1622.0                           NaN
# 4                         2141.0                           NaN
#
#    cumulative_persons_fully_vaccinated  new_vaccine_doses_administered  \
# 0                                  NaN                             NaN
# 1                                  NaN                           460.0
# ...

# %%
df_pfizer = df.filter(['date', 'location_key', 'new_persons_vaccinated_pfizer', 'cumulative_persons_vaccinated_pfizer', 'new_persons_fully_vaccinated_pfizer', 'cumulative_persons_fully_vaccinated_pfizer', 'new_vaccine_doses_administered_pfizer', 'cumulative_vaccine_doses_administered_pfizer'], axis= 1)
df_pfizer.head()
# Out:
#          date location_key  new_persons_vaccinated_pfizer  \
# 0  2021-01-25           AD                            NaN
# 1  2021-02-01           AD                            NaN
# 2  2021-02-10           AD                            NaN
# 3  2021-02-12           AD                            NaN
# 4  2021-02-19           AD                            NaN
#
#    cumulative_persons_vaccinated_pfizer  new_persons_fully_vaccinated_pfizer  \
# 0                                   NaN                                  NaN
# 1                                   NaN                                  NaN
# 2                                   NaN                                  NaN
# 3                                   NaN                                  NaN
# 4                                   NaN                                  NaN
#
#    cumulative_persons_fully_vaccinated_pfizer  \
# 0                                         NaN
# 1                                         NaN
# ...

# %%
df_moderna = df.filter(['date', 'location_key', 'new_persons_vaccinated_moderna', 'cumulative_persons_vaccinated_moderna', 'new_persons_fully_vaccinated_moderna', 'cumulative_persons_fully_vaccinated_moderna', 'new_vaccine_doses_administered_moderna', 'cumulative_vaccine_doses_administered_moderna'], axis= 1)
df_moderna.head()
# Out:
#          date location_key  new_persons_vaccinated_moderna  \
# 0  2021-01-25           AD                             NaN
# 1  2021-02-01           AD                             NaN
# 2  2021-02-10           AD                             NaN
# 3  2021-02-12           AD                             NaN
# 4  2021-02-19           AD                             NaN
#
#    cumulative_persons_vaccinated_moderna  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
#
#    new_persons_fully_vaccinated_moderna  \
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
#
#    cumulative_persons_fully_vaccinated_moderna  \
# 0                                          NaN
# ...

# %%
df_janssen = df.filter(['date', 'location_key', 'new_persons_vaccinated_janssen', 'cumulative_persons_vaccinated_janssen', 'new_persons_fully_vaccinated_janssen', 'cumulative_persons_fully_vaccinated_janssen', 'new_vaccine_doses_administered_janssen', 'cumulative_vaccine_doses_administered_janssen'], axis= 1)
df_janssen.head()
# Out:
#          date location_key  new_persons_vaccinated_janssen  \
# 0  2021-01-25           AD                             NaN
# 1  2021-02-01           AD                             NaN
# 2  2021-02-10           AD                             NaN
# 3  2021-02-12           AD                             NaN
# 4  2021-02-19           AD                             NaN
#
#    cumulative_persons_vaccinated_janssen  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
#
#    new_persons_fully_vaccinated_janssen  \
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
#
#    cumulative_persons_fully_vaccinated_janssen  \
# 0                                          NaN
# ...

# %%
df_sinovac = df.filter(['date', 'location_key', 'new_persons_vaccinated_sinovac', 'total_persons_vaccinated_sinovac', 'new_persons_fully_vaccinated_sinovac', 'total_persons_fully_vaccinated_sinovac', 'new_vaccine_doses_administered_sinovac', 'total_vaccine_doses_administered_sinovac'], axis= 1)
df_sinovac.head()
# Out:
#          date location_key  new_persons_vaccinated_sinovac  \
# 0  2021-01-25           AD                             NaN
# 1  2021-02-01           AD                             NaN
# 2  2021-02-10           AD                             NaN
# 3  2021-02-12           AD                             NaN
# 4  2021-02-19           AD                             NaN
#
#    total_persons_vaccinated_sinovac  new_persons_fully_vaccinated_sinovac  \
# 0                               NaN                                   NaN
# 1                               NaN                                   NaN
# 2                               NaN                                   NaN
# 3                               NaN                                   NaN
# 4                               NaN                                   NaN
#
#    total_persons_fully_vaccinated_sinovac  \
# 0                                     NaN
# 1                                     NaN
# ...

# %%
df_sinovac.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1813965 entries, 0 to 1813964
# Data columns (total 8 columns):
#  #   Column                                    Dtype
# ---  ------                                    -----
#  0   date                                      object
#  1   location_key                              object
#  2   new_persons_vaccinated_sinovac            float64
#  3   total_persons_vaccinated_sinovac          float64
#  4   new_persons_fully_vaccinated_sinovac      float64
#  5   total_persons_fully_vaccinated_sinovac    float64
#  6   new_vaccine_doses_administered_sinovac    float64
#  7   total_vaccine_doses_administered_sinovac  float64
# dtypes: float64(6), object(2)
# memory usage: 110.7+ MB

# %%
#add vaccination provider id column
df_totals['vaccination_provider_id'] = 1
df_totals.head()
# Out:
#          date location_key  new_persons_vaccinated  \
# 0  2021-01-25           AD                     NaN
# 1  2021-02-01           AD                   460.0
# 2  2021-02-10           AD                   255.0
# 3  2021-02-12           AD                   331.0
# 4  2021-02-19           AD                   519.0
#
#    cumulative_persons_vaccinated  new_persons_fully_vaccinated  \
# 0                          576.0                           NaN
# 1                         1036.0                           NaN
# 2                         1291.0                           NaN
# 3                         1622.0                           NaN
# 4                         2141.0                           NaN
#
#    cumulative_persons_fully_vaccinated  new_vaccine_doses_administered  \
# 0                                  NaN                             NaN
# 1                                  NaN                           460.0
# ...

# %%
df_pfizer['vaccination_provider_id'] = 2
df_moderna['vaccination_provider_id'] = 3
df_janssen['vaccination_provider_id'] = 4
df_sinovac['vaccination_provider_id'] = 5

# %%
df_sinovac.head()
# Out:
#          date location_key  new_persons_vaccinated_sinovac  \
# 0  2021-01-25           AD                             NaN
# 1  2021-02-01           AD                             NaN
# 2  2021-02-10           AD                             NaN
# 3  2021-02-12           AD                             NaN
# 4  2021-02-19           AD                             NaN
#
#    total_persons_vaccinated_sinovac  new_persons_fully_vaccinated_sinovac  \
# 0                               NaN                                   NaN
# 1                               NaN                                   NaN
# 2                               NaN                                   NaN
# 3                               NaN                                   NaN
# 4                               NaN                                   NaN
#
#    total_persons_fully_vaccinated_sinovac  \
# 0                                     NaN
# 1                                     NaN
# ...

# %%
#rename columns to merge data
df_pfizer.columns = ['date', 'location_key', 'new_persons_vaccinated', 'cumulative_persons_vaccinated', 'new_persons_fully_vaccinated', 'cumulative_persons_fully_vaccinated', 'new_vaccine_doses_administered', 'cumulative_vaccine_doses_administered', 'vaccination_provider_id']
df_pfizer.head()
# Out:
#          date location_key  new_persons_vaccinated  \
# 0  2021-01-25           AD                     NaN
# 1  2021-02-01           AD                     NaN
# 2  2021-02-10           AD                     NaN
# 3  2021-02-12           AD                     NaN
# 4  2021-02-19           AD                     NaN
#
#    cumulative_persons_vaccinated  new_persons_fully_vaccinated  \
# 0                            NaN                           NaN
# 1                            NaN                           NaN
# 2                            NaN                           NaN
# 3                            NaN                           NaN
# 4                            NaN                           NaN
#
#    cumulative_persons_fully_vaccinated  new_vaccine_doses_administered  \
# 0                                  NaN                             NaN
# 1                                  NaN                             NaN
# ...

# %%
df_moderna.columns = ['date', 'location_key', 'new_persons_vaccinated', 'cumulative_persons_vaccinated', 'new_persons_fully_vaccinated', 'cumulative_persons_fully_vaccinated', 'new_vaccine_doses_administered', 'cumulative_vaccine_doses_administered', 'vaccination_provider_id']
df_moderna.head()
# Out:
#          date location_key  new_persons_vaccinated  \
# 0  2021-01-25           AD                     NaN
# 1  2021-02-01           AD                     NaN
# 2  2021-02-10           AD                     NaN
# 3  2021-02-12           AD                     NaN
# 4  2021-02-19           AD                     NaN
#
#    cumulative_persons_vaccinated  new_persons_fully_vaccinated  \
# 0                            NaN                           NaN
# 1                            NaN                           NaN
# 2                            NaN                           NaN
# 3                            NaN                           NaN
# 4                            NaN                           NaN
#
#    cumulative_persons_fully_vaccinated  new_vaccine_doses_administered  \
# 0                                  NaN                             NaN
# 1                                  NaN                             NaN
# ...

# %%
df_janssen.columns = ['date', 'location_key', 'new_persons_vaccinated', 'cumulative_persons_vaccinated', 'new_persons_fully_vaccinated', 'cumulative_persons_fully_vaccinated', 'new_vaccine_doses_administered', 'cumulative_vaccine_doses_administered', 'vaccination_provider_id']
df_janssen.head()
# Out:
#          date location_key  new_persons_vaccinated  \
# 0  2021-01-25           AD                     NaN
# 1  2021-02-01           AD                     NaN
# 2  2021-02-10           AD                     NaN
# 3  2021-02-12           AD                     NaN
# 4  2021-02-19           AD                     NaN
#
#    cumulative_persons_vaccinated  new_persons_fully_vaccinated  \
# 0                            NaN                           NaN
# 1                            NaN                           NaN
# 2                            NaN                           NaN
# 3                            NaN                           NaN
# 4                            NaN                           NaN
#
#    cumulative_persons_fully_vaccinated  new_vaccine_doses_administered  \
# 0                                  NaN                             NaN
# 1                                  NaN                             NaN
# ...

# %%
df_sinovac.columns = ['date', 'location_key', 'new_persons_vaccinated', 'cumulative_persons_vaccinated', 'new_persons_fully_vaccinated', 'cumulative_persons_fully_vaccinated', 'new_vaccine_doses_administered', 'cumulative_vaccine_doses_administered', 'vaccination_provider_id']
df_sinovac.head()
# Out:
#          date location_key  new_persons_vaccinated  \
# 0  2021-01-25           AD                     NaN
# 1  2021-02-01           AD                     NaN
# 2  2021-02-10           AD                     NaN
# 3  2021-02-12           AD                     NaN
# 4  2021-02-19           AD                     NaN
#
#    cumulative_persons_vaccinated  new_persons_fully_vaccinated  \
# 0                            NaN                           NaN
# 1                            NaN                           NaN
# 2                            NaN                           NaN
# 3                            NaN                           NaN
# 4                            NaN                           NaN
#
#    cumulative_persons_fully_vaccinated  new_vaccine_doses_administered  \
# 0                                  NaN                             NaN
# 1                                  NaN                             NaN
# ...

# %%
#merge all dataframes 
merged_df = pd.concat([df_totals, df_pfizer, df_moderna, df_janssen, df_sinovac], sort=False)
merged_df.head(50)
# Out:
#           date location_key  new_persons_vaccinated  \
# 0   2021-01-25           AD                     NaN
# 1   2021-02-01           AD                   460.0
# 2   2021-02-10           AD                   255.0
# 3   2021-02-12           AD                   331.0
# 4   2021-02-19           AD                   519.0
# 5   2021-02-24           AD                   249.0
# 6   2021-02-26           AD                     0.0
# 7   2021-03-08           AD                    49.0
# 8   2021-03-10           AD                  1211.0
# 9   2021-03-15           AD                  3448.0
# 10  2021-03-19           AD                     0.0
# 11  2021-04-04           AD                     0.0
# 12  2021-04-05           AD                  2683.0
# 13  2021-04-11           AD                     0.0
# 14  2021-04-12           AD                     0.0
# 15  2021-04-19           AD                 11952.0
# 16  2021-04-26           AD                  2089.0
# ...

# %%
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9069825 entries, 0 to 1813964
# Data columns (total 9 columns):
#  #   Column                                 Dtype
# ---  ------                                 -----
#  0   date                                   object
#  1   location_key                           object
#  2   new_persons_vaccinated                 float64
#  3   cumulative_persons_vaccinated          float64
#  4   new_persons_fully_vaccinated           float64
#  5   cumulative_persons_fully_vaccinated    float64
#  6   new_vaccine_doses_administered         float64
#  7   cumulative_vaccine_doses_administered  float64
#  8   vaccination_provider_id                int64
# dtypes: float64(6), int64(1), object(2)
# memory usage: 692.0+ MB

# %%
merged_df.sort_values(by=['date', 'location_key', 'vaccination_provider_id'])
# Out:
#               date location_key  new_persons_vaccinated  \
# 169415  2020-01-25           AU                     NaN
# 169415  2020-01-25           AU                     NaN
# 169415  2020-01-25           AU                     NaN
# 169415  2020-01-25           AU                     NaN
# 169415  2020-01-25           AU                     NaN
# ...            ...          ...                     ...
# 170200  2022-03-20           AU                     0.0
# 170200  2022-03-20           AU                     NaN
# 170200  2022-03-20           AU                     NaN
# 170200  2022-03-20           AU                     NaN
# 170200  2022-03-20           AU                     NaN
#
#         cumulative_persons_vaccinated  new_persons_fully_vaccinated  \
# 169415                            NaN                           NaN
# 169415                            NaN                           NaN
# 169415                            NaN                           NaN
# ...

# %%
#FROM JOSEPH-- Shortened csv country list to match countries information csv
trial_df= merged_df.loc[merged_df['location_key'].isin(['US', 'CA', 'NG', 'CN', 'IN', 'ZW', 'EG', 'CI', 'AU', 'BR', 'MX'])]
trial_df
#trial_df
# Out:
#               date location_key  new_persons_vaccinated  \
# 209293  2020-12-14           CA                     NaN
# 209294  2020-12-15           CA                   722.0
# 209295  2020-12-16           CA                  2298.0
# 209296  2020-12-17           CA                  4254.0
# 209297  2020-12-18           CA                  4017.0
# ...            ...          ...                     ...
# 731451  2022-03-15           US                     NaN
# 731452  2022-03-16           US                     NaN
# 731453  2022-03-17           US                     NaN
# 731454  2022-03-18           US                     NaN
# 731455  2022-03-19           US                     NaN
#
#         cumulative_persons_vaccinated  new_persons_fully_vaccinated  \
# 209293                            5.0                           NaN
# 209294                          727.0                           NaN
# 209295                         3025.0                           NaN
# ...

# %%
trial_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4560 entries, 209293 to 731455
# Data columns (total 9 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   date                                   4560 non-null   object
#  1   location_key                           4560 non-null   object
#  2   new_persons_vaccinated                 911 non-null    float64
#  3   cumulative_persons_vaccinated          912 non-null    float64
#  4   new_persons_fully_vaccinated           2030 non-null   float64
#  5   cumulative_persons_fully_vaccinated    2036 non-null   float64
#  6   new_vaccine_doses_administered         2039 non-null   float64
#  7   cumulative_vaccine_doses_administered  2043 non-null   float64
#  8   vaccination_provider_id                4560 non-null   int64
# dtypes: float64(6), int64(1), object(2)
# memory usage: 356.2+ KB

# %%
#write merged data to new csv for database upload 
merged_df.to_csv('/Users/serendipitousfun/Desktop/Project 2 ETL Group 4/ Resources/transformed_vaccinations.csv')

# %%
#write merged data to new csv for database upload with only 11 countries
trial_df.to_csv('/Users/serendipitousfun/Desktop/Project 2 ETL Group 4/ Resources/trans_countries_vaccinations.csv', index=False)

# %%
#create vaccination id csv
data = [[1, 'vaccination_totals'], [2, 'pfizer'], [3, 'moderna'], [4, 'jassen'], [5, 'sinovac']]
vacc_id_df = pd.DataFrame(data, columns = ['vaccination_provider_id', 'vaccination_provider'])
vacc_id_df
# Out:
#    vaccination_provider_id vaccination_provider
# 0                        1   vaccination_totals
# 1                        2               pfizer
# 2                        3              moderna
# 3                        4               jassen
# 4                        5              sinovac

# %%
vacc_id_df.set_index('vaccination_provider_id')
# Out:
#                         vaccination_provider
# vaccination_provider_id
# 1                         vaccination_totals
# 2                                     pfizer
# 3                                    moderna
# 4                                     jassen
# 5                                    sinovac

# %%
vacc_id_df.to_csv('/Users/serendipitousfun/Desktop/Project 2 ETL Group 4/ Resources/vaccination_id.csv', index=False)

# %%
from sqlalchemy import create_engine

# %%
# append data into postgres tables 
engine = create_engine('postgresql://postgres:password@34.133.202.52/postgres')
vacc_id_df.to_sql('vaccination_providers', engine, if_exists="append", index=False)

# %%
engine = create_engine('postgresql://postgres:password@34.133.202.52/postgres')
trial_df.to_sql('us_vacc_totals_by_provider', engine, if_exists="append", index=False)
